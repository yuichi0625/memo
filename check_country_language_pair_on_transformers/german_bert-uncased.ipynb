# %% [markdown]
# <a href="https://colab.research.google.com/github/yuichi0625/cellar/blob/main/check_country_language_pair_on_transformers/bert_uncased_german.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/ed/d5/f4157a376b8a79489a76ce6cfe147f4f3be1e029b7144fa7b8432e8acb26/transformers-4.4.2-py3-none-any.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 5.7MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 33.4MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 33.0MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=2d81dfe5beaa909d257cfe05ff8c98ad4682b18348958c6072a65048b2e3b114
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.10.1 transformers-4.4.2

# %%
# !wget https://raw.githubusercontent.com/yuichi0625/cellar/main/check_country_language_pair_on_transformers/countries.csv
# Out:
# --2021-03-23 16:31:02--  https://raw.githubusercontent.com/yuichi0625/cellar/main/check_country_language_pair_on_transformers/countries.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7068 (6.9K) [text/plain]
# Saving to: ‘countries.csv’
#
# countries.csv       100%[===================>]   6.90K  --.-KB/s    in 0s
#
# 2021-03-23 16:31:03 (66.3 MB/s) - ‘countries.csv’ saved [7068/7068]

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForMaskedLM
pd.set_option('display.max_rows', 500)

tokenizer = AutoTokenizer.from_pretrained('bert-base-german-dbmdz-uncased')
model = AutoModelForMaskedLM.from_pretrained('bert-base-german-dbmdz-uncased')

sequence = 'Ich wohne in {}, und ich spreche {}.'

rows = []
for name in pd.read_csv('countries.csv')['de'].sort_values():
  input = tokenizer.encode(sequence.format(name, tokenizer.mask_token), return_tensors='pt')
  mask_token_index = torch.where(input == tokenizer.mask_token_id)[1]

  token_logits = model(input).logits[0]
  mask_token_logits = token_logits[mask_token_index, :][0]
  mask_token_probs = torch.softmax(mask_token_logits, dim=0)

  candidate_indices = torch.topk(mask_token_logits, k=3, dim=0).indices.tolist()
  result = [f'{tokenizer.decode([ci])} ({mask_token_probs[ci] * 100:.0f}%)' for ci in candidate_indices]

  rows.append([name, *result])
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=247333.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=486583.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442256365.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at bert-base-german-dbmdz-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
pd.DataFrame(rows, columns=['Land', 'Sprache(top1)', 'Sprache(top2)', 'Sprache(top3)'])
# Out:
#                                    Land  ...      Sprache(top3)
# 0                           Afghanistan  ...      russisch (9%)
# 1                              Albanien  ...   italienisch (7%)
# 2                              Algerien  ...      arabisch (9%)
# 3                               Andorra  ...  italienisch (17%)
# 4                                Angola  ...      spanisch (9%)
# 5                   Antigua und Barbuda  ...      deutsch (12%)
# 6                           Argentinien  ...     spanisch (22%)
# 7                              Armenien  ...     englisch (20%)
# 8                         Aserbaidschan  ...      deutsch (19%)
# 9                            Australien  ...      spanisch (3%)
# 10                              Bahamas  ...       deutsch (9%)
# 11                              Bahrain  ...      arabisch (9%)
# 12                          Bangladesch  ...      arabisch (3%)
# 13                             Barbados  ...      spanisch (7%)
# 14                              Belgien  ...      spanisch (3%)
# 15                               Belize  ...     spanisch (10%)
# 16                                Benin  ...      arabisch (8%)
# 17                               Bhutan  ...      arabisch (2%)
# 18                             Bolivien  ...     spanisch (22%)
# 19              Bosnien und Herzegowina  ...      russisch (9%)
# 20                             Botswana  ...      spanisch (2%)
# 21                            Brasilien  ...     spanisch (16%)
# 22                               Brunei  ...   italienisch (4%)
# 23                            Bulgarien  ...     russisch (19%)
# 24                         Burkina Faso  ...      spanisch (5%)
# 25                              Burundi  ...   italienisch (3%)
# 26                                Chile  ...     spanisch (22%)
# 27                                China  ...      russisch (5%)
# 28                           Costa Rica  ...      deutsch (13%)
# 29         Demokratische Republik Kongo  ...      spanisch (3%)
# 30                          Deutschland  ...      spanisch (3%)
# 31                             Dominica  ...       deutsch (9%)
# 32              Dominikanische Republik  ...      deutsch (11%)
# 33                            Dschibuti  ...     arabisch (11%)
# 34                             Dänemark  ...      russisch (2%)
# 35                              Ecuador  ...      deutsch (23%)
# 36                          El Salvador  ...      deutsch (13%)
# 37                       Elfenbeinküste  ...     spanisch (10%)
# 38                              Eritrea  ...      arabisch (8%)
# 39                              Estland  ...     russisch (16%)
# 40                             Eswatini  ...      russisch (8%)
# 41                              Fidschi  ...      spanisch (5%)
# 42                             Finnland  ...     russisch (10%)
# 43                           Frankreich  ...   italienisch (5%)
# 44   Föderierte Staaten von Mikronesien  ...      spanisch (6%)
# 45                                Gabun  ...      spanisch (5%)
# 46                               Gambia  ...      spanisch (3%)
# 47                             Georgien  ...     englisch (18%)
# 48                                Ghana  ...      spanisch (3%)
# 49                              Grenada  ...      spanisch (6%)
# 50                         Griechenland  ...     englisch (21%)
# 51                            Guatemala  ...      deutsch (13%)
# 52                               Guinea  ...      spanisch (7%)
# 53                        Guinea-Bissau  ...     spanisch (10%)
# 54                               Guyana  ...      deutsch (12%)
# 55                                Haiti  ...      deutsch (12%)
# 56                             Honduras  ...      deutsch (14%)
# 57                               Indien  ...      spanisch (2%)
# 58                           Indonesien  ...      spanisch (5%)
# 59                                 Irak  ...     arabisch (15%)
# 60                                 Iran  ...     arabisch (15%)
# 61                               Irland  ...   italienisch (2%)
# 62                               Island  ...      spanisch (4%)
# 63                               Israel  ...      arabisch (9%)
# 64                              Italien  ...     englisch (17%)
# 65                              Jamaika  ...      spanisch (7%)
# 66                                Japan  ...      russisch (4%)
# 67                                Jemen  ...      deutsch (15%)
# 68                            Jordanien  ...      deutsch (20%)
# 69                           Kambodscha  ...      spanisch (3%)
# 70                              Kamerun  ...      spanisch (6%)
# 71                               Kanada  ...      spanisch (4%)
# 72                            Kap Verde  ...      deutsch (16%)
# 73                           Kasachstan  ...      deutsch (15%)
# 74                                Katar  ...      deutsch (14%)
# 75                                Kenia  ...      spanisch (3%)
# 76                          Kirgisistan  ...      deutsch (15%)
# 77                             Kiribati  ...      russisch (2%)
# 78                            Kolumbien  ...      deutsch (22%)
# 79                              Komoren  ...   italienisch (6%)
# 80                               Kosovo  ...     russisch (11%)
# 81                             Kroatien  ...   italienisch (9%)
# 82                                 Kuba  ...      deutsch (18%)
# 83                               Kuwait  ...      arabisch (8%)
# 84                                 Laos  ...      spanisch (6%)
# 85                              Lesotho  ...      spanisch (2%)
# 86                             Lettland  ...     englisch (16%)
# 87                              Libanon  ...      deutsch (18%)
# 88                              Liberia  ...      spanisch (6%)
# 89                               Libyen  ...      arabisch (9%)
# 90                        Liechtenstein  ...   italienisch (5%)
# 91                              Litauen  ...     englisch (16%)
# 92                            Luxemburg  ...   italienisch (4%)
# 93                           Madagaskar  ...      spanisch (6%)
# 94                               Malawi  ...      spanisch (2%)
# 95                             Malaysia  ...      spanisch (5%)
# 96                            Malediven  ...      spanisch (5%)
# 97                                 Mali  ...      arabisch (8%)
# 98                                Malta  ...  italienisch (13%)
# 99                              Marokko  ...     spanisch (12%)
# 100                      Marshallinseln  ...      spanisch (4%)
# 101                         Mauretanien  ...      deutsch (13%)
# 102                           Mauritius  ...      spanisch (8%)
# 103                              Mexiko  ...      deutsch (19%)
# 104                              Monaco  ...   italienisch (9%)
# 105                            Mongolei  ...     russisch (23%)
# 106                          Montenegro  ...   italienisch (8%)
# 107                            Mosambik  ...      spanisch (7%)
# 108                             Myanmar  ...      spanisch (2%)
# 109                             Namibia  ...      spanisch (2%)
# 110                               Nauru  ...      spanisch (4%)
# 111                               Nepal  ...      russisch (2%)
# 112                          Neuseeland  ...      spanisch (2%)
# 113                           Nicaragua  ...      deutsch (16%)
# 114                         Niederlande  ...      spanisch (4%)
# 115                               Niger  ...      arabisch (7%)
# 116                             Nigeria  ...      spanisch (4%)
# 117                           Nordkorea  ...     russisch (12%)
# 118                      Nordmazedonien  ...  italienisch (14%)
# 119                            Norwegen  ...      russisch (3%)
# 120                                Oman  ...      deutsch (13%)
# 121                            Osttimor  ...      spanisch (7%)
# 122                            Pakistan  ...      arabisch (4%)
# 123                               Palau  ...     spanisch (11%)
# 124                           Palestine  ...      spanisch (7%)
# 125                              Panama  ...      deutsch (11%)
# 126                     Papua-Neuguinea  ...      spanisch (3%)
# 127                            Paraguay  ...      deutsch (20%)
# 128                                Peru  ...      deutsch (26%)
# 129                         Philippinen  ...     spanisch (17%)
# 130                               Polen  ...     englisch (20%)
# 131                            Portugal  ...     spanisch (15%)
# 132                      Republik Kongo  ...      russisch (4%)
# 133                     Republik Moldau  ...     englisch (21%)
# 134                     Republik Zypern  ...   griechisch (10%)
# 135                              Ruanda  ...      spanisch (3%)
# 136                            Rumänien  ...      russisch (9%)
# 137                            Russland  ...     englisch (20%)
# 138                           Salomonen  ...      spanisch (3%)
# 139                              Sambia  ...      spanisch (2%)
# 140                               Samoa  ...      spanisch (5%)
# 141                          San Marino  ...     spanisch (11%)
# 142                       Saudi-Arabien  ...      deutsch (14%)
# 143                            Schweden  ...      russisch (4%)
# 144                             Schweiz  ...   italienisch (8%)
# 145                             Senegal  ...      spanisch (6%)
# 146                             Serbien  ...     russisch (11%)
# 147                          Seychellen  ...      spanisch (5%)
# 148                        Sierra Leone  ...      spanisch (6%)
# 149                            Simbabwe  ...      spanisch (1%)
# 150                            Singapur  ...      spanisch (4%)
# 151                            Slowakei  ...     russisch (14%)
# 152                           Slowenien  ...   italienisch (9%)
# 153                             Somalia  ...      arabisch (4%)
# 154                             Spanien  ...      deutsch (23%)
# 155                           Sri Lanka  ...      spanisch (2%)
# 156                 St. Kitts und Nevis  ...   italienisch (3%)
# 157                           St. Lucia  ...   italienisch (9%)
# 158      St. Vincent und die Grenadinen  ...      spanisch (8%)
# 159                               Sudan  ...      arabisch (8%)
# 160                            Suriname  ...      spanisch (6%)
# 161                              Syrien  ...      deutsch (21%)
# 162               São Tomé und Príncipe  ...   italienisch (7%)
# 163                           Südafrika  ...      spanisch (3%)
# 164                            Südkorea  ...      russisch (4%)
# 165                            Südsudan  ...      arabisch (7%)
# 166                       Tadschikistan  ...      deutsch (16%)
# 167                            Tansania  ...      spanisch (3%)
# 168                            Thailand  ...      spanisch (3%)
# 169                                Togo  ...   italienisch (5%)
# 170                               Tonga  ...      spanisch (8%)
# 171                 Trinidad und Tobago  ...       deutsch (5%)
# 172                              Tschad  ...      arabisch (8%)
# 173                          Tschechien  ...     russisch (11%)
# 174                            Tunesien  ...     arabisch (18%)
# 175                        Turkmenistan  ...     englisch (21%)
# 176                              Tuvalu  ...     spanisch (10%)
# 177                              Türkei  ...      arabisch (5%)
# 178                              Uganda  ...      spanisch (2%)
# 179                             Ukraine  ...     englisch (12%)
# 180                              Ungarn  ...      russisch (5%)
# 181                             Uruguay  ...      deutsch (18%)
# 182                          Usbekistan  ...     englisch (15%)
# 183                             Vanuatu  ...      spanisch (5%)
# 184                        Vatikanstadt  ...      deutsch (13%)
# 185                           Venezuela  ...      deutsch (23%)
# 186        Vereinigte Arabische Emirate  ...      arabisch (6%)
# 187                  Vereinigte Staaten  ...      spanisch (6%)
# 188              Vereinigtes Königreich  ...   italienisch (1%)
# 189                             Vietnam  ...      spanisch (4%)
# 190                        Weißrussland  ...      englisch (8%)
# 191        Zentralafrikanische Republik  ...      spanisch (4%)
# 192                             ÁEypten  ...   griechisch (15%)
# 193                    Äquatorialguinea  ...      spanisch (9%)
# 194                           Äthiopien  ...      arabisch (4%)
# 195                          Österreich  ...   italienisch (3%)
#
# [196 rows x 4 columns]

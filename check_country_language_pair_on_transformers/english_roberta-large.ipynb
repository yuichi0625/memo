# %% [markdown]
# <a href="https://colab.research.google.com/github/yuichi0625/cellar/blob/main/check_country_language_pair_on_transformers/roberta_large_english.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/ed/d5/f4157a376b8a79489a76ce6cfe147f4f3be1e029b7144fa7b8432e8acb26/transformers-4.4.2-py3-none-any.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 6.6MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 41.6MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 46.6MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=db2a33af7829e36a5dd3beda5ab54b6bcd111fd77be31638866dbdd900e6cb75
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.10.1 transformers-4.4.2

# %%
# !wget https://raw.githubusercontent.com/yuichi0625/cellar/main/check_country_language_pair_on_transformers/countries.csv
# Out:
# --2021-03-23 16:42:50--  https://raw.githubusercontent.com/yuichi0625/cellar/main/check_country_language_pair_on_transformers/countries.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7068 (6.9K) [text/plain]
# Saving to: ‘countries.csv’
#
# countries.csv       100%[===================>]   6.90K  --.-KB/s    in 0s
#
# 2021-03-23 16:42:50 (73.6 MB/s) - ‘countries.csv’ saved [7068/7068]

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForMaskedLM
pd.set_option('display.max_rows', 500)

tokenizer = AutoTokenizer.from_pretrained('roberta-large')
model = AutoModelForMaskedLM.from_pretrained('roberta-large')

sequence = 'I live in {} and I speak {}.'

rows = []
for name in pd.read_csv('countries.csv')['en'].sort_values():
  input = tokenizer.encode(sequence.format(name, tokenizer.mask_token), return_tensors='pt')
  mask_token_index = torch.where(input == tokenizer.mask_token_id)[1]

  token_logits = model(input).logits[0]
  mask_token_logits = token_logits[mask_token_index, :][0]
  mask_token_probs = torch.softmax(mask_token_logits, dim=0)

  candidate_indices = torch.topk(mask_token_logits, k=3, dim=0).indices.tolist()
  result = [f'{tokenizer.decode([ci])} ({mask_token_probs[ci] * 100:.0f}%)' for ci in candidate_indices]

  rows.append([name, *result])
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=482.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898823.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355863.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1425941629.0, style=ProgressStyle(descr…

# %%
pd.DataFrame(rows, columns=['country', 'language(top1)', 'language(top2)', 'language(top3)'])
# Out:
#                               country  ...     language(top3)
# 0                         Afghanistan  ...       Persian (4%)
# 1                             Albania  ...        French (9%)
# 2                             Algeria  ...      English (10%)
# 3                             Andorra  ...      English (20%)
# 4                              Angola  ...       Spanish (8%)
# 5                 Antigua and Barbuda  ...    Portuguese (6%)
# 6                           Argentina  ...        French (8%)
# 7                             Armenia  ...      English (21%)
# 8                           Australia  ...      Mandarin (4%)
# 9                             Austria  ...        French (7%)
# 10                         Azerbaijan  ...       Turkish (5%)
# 11                            Bahrain  ...       Persian (2%)
# 12                         Bangladesh  ...        Arabic (3%)
# 13                           Barbados  ...        French (8%)
# 14                            Belarus  ...        German (6%)
# 15                            Belgium  ...      English (16%)
# 16                             Belize  ...    Portuguese (6%)
# 17                              Benin  ...       Spanish (3%)
# 18                             Bhutan  ...       Tibetan (4%)
# 19                            Bolivia  ...    Portuguese (9%)
# 20             Bosnia and Herzegovina  ...      Serbian (10%)
# 21                           Botswana  ...        German (3%)
# 22                             Brazil  ...       Spanish (4%)
# 23                             Brunei  ...      Chinese (10%)
# 24                           Bulgaria  ...      Russian (17%)
# 25                       Burkina Faso  ...    Portuguese (2%)
# 26                            Burundi  ...        German (4%)
# 27                           Cambodia  ...          Thai (4%)
# 28                           Cameroon  ...       Spanish (2%)
# 29                             Canada  ...        German (2%)
# 30                         Cape Verde  ...        French (6%)
# 31           Central African Republic  ...       Spanish (1%)
# 32                               Chad  ...       Arabic (14%)
# 33                              Chile  ...        French (3%)
# 34                              China  ...      English (19%)
# 35                           Colombia  ...    Portuguese (8%)
# 36                            Comoros  ...    Portuguese (6%)
# 37                         Costa Rica  ...   Portuguese (10%)
# 38                            Croatia  ...        German (7%)
# 39                               Cuba  ...       Russian (5%)
# 40                             Cyprus  ...        French (8%)
# 41                     Czech Republic  ...       Russian (8%)
# 42   Democratic Republic of the Congo  ...        German (7%)
# 43                            Denmark  ...        German (6%)
# 44                           Djibouti  ...      English (19%)
# 45                           Dominica  ...      Spanish (14%)
# 46                 Dominican Republic  ...    Portuguese (8%)
# 47                         East Timor  ...   Indonesian (19%)
# 48                            Ecuador  ...        French (6%)
# 49                              Egypt  ...        French (5%)
# 50                        El Salvador  ...    Portuguese (1%)
# 51                  Equatorial Guinea  ...   Portuguese (15%)
# 52                            Eritrea  ...        Somali (6%)
# 53                            Estonia  ...       German (13%)
# 54                           Eswatini  ...        French (9%)
# 55                           Ethiopia  ...        Somali (8%)
# 56     Federated States of Micronesia  ...        French (6%)
# 57                               Fiji  ...        French (6%)
# 58                            Finland  ...      English (12%)
# 59                             France  ...        German (3%)
# 60                              Gabon  ...       Spanish (2%)
# 61                            Georgia  ...        German (7%)
# 62                            Germany  ...        French (2%)
# 63                              Ghana  ...        German (1%)
# 64                             Greece  ...        French (6%)
# 65                            Grenada  ...       French (12%)
# 66                          Guatemala  ...        French (2%)
# 67                             Guinea  ...    Portuguese (3%)
# 68                      Guinea-Bissau  ...   Portuguese (30%)
# 69                             Guyana  ...        French (4%)
# 70                              Haiti  ...    Portuguese (2%)
# 71                           Honduras  ...    Portuguese (3%)
# 72                            Hungary  ...        German (4%)
# 73                            Iceland  ...       Swedish (5%)
# 74                              India  ...         Tamil (2%)
# 75                          Indonesia  ...         Dutch (8%)
# 76                               Iran  ...       Arabic (12%)
# 77                               Iraq  ...      Kurdish (13%)
# 78                            Ireland  ...        French (8%)
# 79                             Israel  ...      English (13%)
# 80                              Italy  ...        French (6%)
# 81                        Ivory Coast  ...    Portuguese (2%)
# 82                            Jamaica  ...    Portuguese (3%)
# 83                              Japan  ...        Korean (1%)
# 84                             Jordan  ...        French (2%)
# 85                         Kazakhstan  ...        Kazakh (3%)
# 86                              Kenya  ...        Arabic (2%)
# 87                           Kiribati  ...    Portuguese (3%)
# 88                             Kosovo  ...       Serbian (9%)
# 89                             Kuwait  ...        French (2%)
# 90                         Kyrgyzstan  ...        German (2%)
# 91                               Laos  ...       Chinese (6%)
# 92                             Latvia  ...       German (11%)
# 93                            Lebanon  ...       French (13%)
# 94                            Lesotho  ...    Portuguese (3%)
# 95                            Liberia  ...       Spanish (1%)
# 96                              Libya  ...        French (5%)
# 97                      Liechtenstein  ...         Dutch (3%)
# 98                          Lithuania  ...        German (9%)
# 99                         Luxembourg  ...      English (17%)
# 100                        Madagascar  ...    Portuguese (5%)
# 101                            Malawi  ...        German (2%)
# 102                          Malaysia  ...      Chinese (12%)
# 103                          Maldives  ...         Hindi (8%)
# 104                              Mali  ...        Arabic (4%)
# 105                             Malta  ...       Spanish (7%)
# 106                  Marshall Islands  ...      Japanese (5%)
# 107                        Mauritania  ...        Arabic (9%)
# 108                         Mauritius  ...    Portuguese (3%)
# 109                            Mexico  ...        French (3%)
# 110                           Moldova  ...     Romanian (17%)
# 111                            Monaco  ...       Spanish (2%)
# 112                          Mongolia  ...     Mandarin (15%)
# 113                        Montenegro  ...      Russian (12%)
# 114                           Morocco  ...      English (11%)
# 115                        Mozambique  ...        French (7%)
# 116                           Myanmar  ...          Thai (2%)
# 117                           Namibia  ...    Portuguese (5%)
# 118                             Nauru  ...        French (6%)
# 119                             Nepal  ...       Chinese (1%)
# 120                       Netherlands  ...       German (12%)
# 121                       New Zealand  ...        German (6%)
# 122                         Nicaragua  ...        French (5%)
# 123                             Niger  ...        Arabic (7%)
# 124                           Nigeria  ...        Arabic (2%)
# 125                       North Korea  ...       Russian (7%)
# 126                   North Macedonia  ...      Turkish (12%)
# 127                            Norway  ...       Swedish (4%)
# 128                              Oman  ...       Persian (1%)
# 129                          Pakistan  ...        Arabic (4%)
# 130                             Palau  ...     Mandarin (12%)
# 131                         Palestine  ...       Hebrew (13%)
# 132                            Panama  ...        French (3%)
# 133                  Papua New Guinea  ...       Chinese (3%)
# 134                          Paraguay  ...    Portuguese (8%)
# 135                              Peru  ...   Portuguese (14%)
# 136                       Philippines  ...       Chinese (8%)
# 137                            Poland  ...       German (10%)
# 138                          Portugal  ...       Spanish (4%)
# 139                             Qatar  ...        French (3%)
# 140             Republic of the Congo  ...        German (6%)
# 141                           Romania  ...       Russian (7%)
# 142                            Russia  ...        German (0%)
# 143                            Rwanda  ...       Russian (3%)
# 144             Saint Kitts and Nevis  ...        French (9%)
# 145                       Saint Lucia  ...       Spanish (8%)
# 146  Saint Vincent and the Grenadines  ...      Spanish (11%)
# 147                             Samoa  ...        French (5%)
# 148                        San Marino  ...       Spanish (8%)
# 149                      Saudi Arabia  ...        French (1%)
# 150                           Senegal  ...       Spanish (3%)
# 151                            Serbia  ...      Russian (15%)
# 152                        Seychelles  ...    Portuguese (5%)
# 153                      Sierra Leone  ...       Spanish (2%)
# 154                         Singapore  ...      Chinese (13%)
# 155                          Slovakia  ...    Hungarian (10%)
# 156                          Slovenia  ...       Swedish (9%)
# 157                   Solomon Islands  ...       Chinese (3%)
# 158                           Somalia  ...      English (26%)
# 159                      South Africa  ...        German (7%)
# 160                       South Korea  ...       Chinese (5%)
# 161                       South Sudan  ...        Somali (4%)
# 162                             Spain  ...       English (9%)
# 163                         Sri Lanka  ...         Hindi (4%)
# 164                             Sudan  ...        Somali (3%)
# 165                          Suriname  ...      Spanish (16%)
# 166                            Sweden  ...        German (3%)
# 167                       Switzerland  ...       English (9%)
# 168                             Syria  ...       Russian (5%)
# 169             São Tomé and Príncipe  ...       French (13%)
# 170                        Tajikistan  ...       Turkish (4%)
# 171                          Tanzania  ...        German (2%)
# 172                          Thailand  ...      Mandarin (5%)
# 173                       The Bahamas  ...    Portuguese (3%)
# 174                        The Gambia  ...       Spanish (2%)
# 175                              Togo  ...    Portuguese (5%)
# 176                             Tonga  ...       Spanish (7%)
# 177               Trinidad and Tobago  ...        French (4%)
# 178                           Tunisia  ...      English (19%)
# 179                            Turkey  ...        Arabic (8%)
# 180                      Turkmenistan  ...       Turkish (8%)
# 181                            Tuvalu  ...      Mandarin (5%)
# 182                            Uganda  ...       Russian (2%)
# 183                           Ukraine  ...       English (9%)
# 184              United Arab Emirates  ...        French (3%)
# 185                    United Kingdom  ...        German (4%)
# 186                     United States  ...        French (2%)
# 187                           Uruguay  ...   Portuguese (13%)
# 188                        Uzbekistan  ...         Uzbek (6%)
# 189                           Vanuatu  ...         Dutch (5%)
# 190                      Vatican City  ...       Spanish (7%)
# 191                         Venezuela  ...        French (4%)
# 192                           Vietnam  ...       French (11%)
# 193                             Yemen  ...        French (1%)
# 194                            Zambia  ...        German (3%)
# 195                          Zimbabwe  ...       Spanish (1%)
#
# [196 rows x 4 columns]

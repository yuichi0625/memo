# %% [markdown]
# <a href="https://colab.research.google.com/github/yuichi0625/cellar/blob/main/check_country_language_pair_on_transformers/distilbert_uncased_english.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/ed/d5/f4157a376b8a79489a76ce6cfe147f4f3be1e029b7144fa7b8432e8acb26/transformers-4.4.2-py3-none-any.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 11.7MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 47.2MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 49.6MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=e9e978a7c26b3cd5750be8e77d193445cb943f7116d85c63b7612984556f9540
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.10.1 transformers-4.4.2

# %%
# !wget https://raw.githubusercontent.com/yuichi0625/cellar/main/check_country_language_pair_on_transformers/countries.csv
# Out:
# --2021-03-23 16:40:55--  https://raw.githubusercontent.com/yuichi0625/cellar/main/check_country_language_pair_on_transformers/countries.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7068 (6.9K) [text/plain]
# Saving to: ‘countries.csv’
#
# countries.csv       100%[===================>]   6.90K  --.-KB/s    in 0s
#
# 2021-03-23 16:40:55 (104 MB/s) - ‘countries.csv’ saved [7068/7068]

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForMaskedLM
pd.set_option('display.max_rows', 500)

tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')
model = AutoModelForMaskedLM.from_pretrained('distilbert-base-uncased')

sequence = 'I live in {} and I speak {}.'

rows = []
for name in pd.read_csv('countries.csv')['en'].sort_values():
  input = tokenizer.encode(sequence.format(name, tokenizer.mask_token), return_tensors='pt')
  mask_token_index = torch.where(input == tokenizer.mask_token_id)[1]

  token_logits = model(input).logits[0]
  mask_token_logits = token_logits[mask_token_index, :][0]
  mask_token_probs = torch.softmax(mask_token_logits, dim=0)

  candidate_indices = torch.topk(mask_token_logits, k=3, dim=0).indices.tolist()
  result = [f'{tokenizer.decode([ci])} ({mask_token_probs[ci] * 100:.0f}%)' for ci in candidate_indices]

  rows.append([name, *result])
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=267967963.0, style=ProgressStyle(descri…

# %%
pd.DataFrame(rows, columns=['country', 'language(top1)', 'language(top2)', 'language(top3)'])
# Out:
#                               country  ...    language(top3)
# 0                         Afghanistan  ...     english (13%)
# 1                             Albania  ...      italian (3%)
# 2                             Algeria  ...      english (9%)
# 3                             Andorra  ...      english (7%)
# 4                              Angola  ...      spanish (9%)
# 5                 Antigua and Barbuda  ...       creole (5%)
# 6                           Argentina  ...      italian (6%)
# 7                             Armenia  ...      english (5%)
# 8                           Australia  ...       french (5%)
# 9                             Austria  ...     italian (11%)
# 10                         Azerbaijan  ...      persian (8%)
# 11                            Bahrain  ...     english (12%)
# 12                         Bangladesh  ...     english (19%)
# 13                           Barbados  ...       french (8%)
# 14                            Belarus  ...      english (2%)
# 15                            Belgium  ...      english (9%)
# 16                             Belize  ...       french (4%)
# 17                              Benin  ...   portuguese (7%)
# 18                             Bhutan  ...     tibetan (13%)
# 19                            Bolivia  ...       french (3%)
# 20             Bosnia and Herzegovina  ...    croatian (16%)
# 21                           Botswana  ...       french (5%)
# 22                             Brazil  ...     english (10%)
# 23                             Brunei  ...      arabic (10%)
# 24                           Bulgaria  ...      english (5%)
# 25                       Burkina Faso  ...       arabic (3%)
# 26                            Burundi  ...      spanish (5%)
# 27                           Cambodia  ...       french (5%)
# 28                           Cameroon  ...       arabic (7%)
# 29                             Canada  ...      russian (8%)
# 30                         Cape Verde  ...      spanish (4%)
# 31           Central African Republic  ...       arabic (4%)
# 32                               Chad  ...      spanish (8%)
# 33                              Chile  ...       french (4%)
# 34                              China  ...   cantonese (13%)
# 35                           Colombia  ...       french (4%)
# 36                            Comoros  ...     english (13%)
# 37                         Costa Rica  ...       french (2%)
# 38                            Croatia  ...      italian (3%)
# 39                               Cuba  ...       french (3%)
# 40                             Cyprus  ...     english (10%)
# 41                     Czech Republic  ...      english (4%)
# 42   Democratic Republic of the Congo  ...   portuguese (4%)
# 43                            Denmark  ...      swedish (4%)
# 44                           Djibouti  ...     english (11%)
# 45                           Dominica  ...      french (17%)
# 46                 Dominican Republic  ...       french (5%)
# 47                         East Timor  ...  indonesian (16%)
# 48                            Ecuador  ...       french (4%)
# 49                              Egypt  ...       coptic (6%)
# 50                        El Salvador  ...       french (4%)
# 51                  Equatorial Guinea  ...     spanish (13%)
# 52                            Eritrea  ...      italian (9%)
# 53                            Estonia  ...      finnish (6%)
# 54                           Eswatini  ...         urdu (8%)
# 55                           Ethiopia  ...      somali (10%)
# 56     Federated States of Micronesia  ...       french (7%)
# 57                               Fiji  ...     hawaiian (7%)
# 58                            Finland  ...      russian (7%)
# 59                             France  ...      spanish (5%)
# 60                              Gabon  ...      spanish (9%)
# 61                            Georgia  ...     spanish (11%)
# 62                            Germany  ...      french (13%)
# 63                              Ghana  ...       french (4%)
# 64                             Greece  ...       french (2%)
# 65                            Grenada  ...     spanish (12%)
# 66                          Guatemala  ...       french (3%)
# 67                             Guinea  ...      arabic (14%)
# 68                      Guinea-Bissau  ...     english (11%)
# 69                             Guyana  ...      french (11%)
# 70                              Haiti  ...      spanish (9%)
# 71                           Honduras  ...       french (3%)
# 72                            Hungary  ...      russian (2%)
# 73                            Iceland  ...      swedish (2%)
# 74                              India  ...       hindi (15%)
# 75                          Indonesia  ...     japanese (5%)
# 76                               Iran  ...         urdu (9%)
# 77                               Iraq  ...      persian (8%)
# 78                            Ireland  ...        welsh (9%)
# 79                             Israel  ...     english (10%)
# 80                              Italy  ...      spanish (6%)
# 81                        Ivory Coast  ...       arabic (6%)
# 82                            Jamaica  ...       french (5%)
# 83                              Japan  ...       korean (2%)
# 84                             Jordan  ...     spanish (11%)
# 85                         Kazakhstan  ...      english (4%)
# 86                              Kenya  ...       french (4%)
# 87                           Kiribati  ...     hawaiian (9%)
# 88                             Kosovo  ...      english (5%)
# 89                             Kuwait  ...     persian (11%)
# 90                         Kyrgyzstan  ...      persian (3%)
# 91                               Laos  ...     english (11%)
# 92                             Latvia  ...      english (4%)
# 93                            Lebanon  ...      english (8%)
# 94                            Lesotho  ...    afrikaans (6%)
# 95                            Liberia  ...       french (8%)
# 96                              Libya  ...      italian (7%)
# 97                      Liechtenstein  ...     russian (12%)
# 98                          Lithuania  ...      latvian (8%)
# 99                         Luxembourg  ...       german (6%)
# 100                        Madagascar  ...     spanish (11%)
# 101                            Malawi  ...   portuguese (3%)
# 102                          Malaysia  ...         urdu (7%)
# 103                          Maldives  ...      arabic (10%)
# 104                              Mali  ...      arabic (17%)
# 105                             Malta  ...     english (13%)
# 106                  Marshall Islands  ...    japanese (11%)
# 107                        Mauritania  ...      english (8%)
# 108                         Mauritius  ...     gujarati (4%)
# 109                            Mexico  ...       french (3%)
# 110                           Moldova  ...      english (4%)
# 111                            Monaco  ...     spanish (13%)
# 112                          Mongolia  ...      english (1%)
# 113                        Montenegro  ...     albanian (9%)
# 114                           Morocco  ...      french (19%)
# 115                        Mozambique  ...     spanish (10%)
# 116                           Myanmar  ...         urdu (2%)
# 117                           Namibia  ...       french (4%)
# 118                             Nauru  ...       french (4%)
# 119                             Nepal  ...         urdu (2%)
# 120                       Netherlands  ...       french (6%)
# 121                       New Zealand  ...     hawaiian (6%)
# 122                         Nicaragua  ...      italian (3%)
# 123                             Niger  ...     english (12%)
# 124                           Nigeria  ...     nigerian (4%)
# 125                       North Korea  ...     japanese (4%)
# 126                   North Macedonia  ...      serbian (7%)
# 127                            Norway  ...      swedish (6%)
# 128                              Oman  ...     english (13%)
# 129                          Pakistan  ...      punjabi (1%)
# 130                             Palau  ...       french (6%)
# 131                         Palestine  ...      yiddish (9%)
# 132                            Panama  ...       french (3%)
# 133                  Papua New Guinea  ...     japanese (8%)
# 134                          Paraguay  ...      italian (8%)
# 135                              Peru  ...       french (3%)
# 136                       Philippines  ...     filipino (5%)
# 137                            Poland  ...      russian (6%)
# 138                          Portugal  ...      english (4%)
# 139                             Qatar  ...         urdu (8%)
# 140             Republic of the Congo  ...   portuguese (5%)
# 141                           Romania  ...       french (3%)
# 142                            Russia  ...      yiddish (1%)
# 143                            Rwanda  ...      spanish (4%)
# 144             Saint Kitts and Nevis  ...       french (6%)
# 145                       Saint Lucia  ...      french (10%)
# 146  Saint Vincent and the Grenadines  ...      french (12%)
# 147                             Samoa  ...      italian (6%)
# 148                        San Marino  ...      english (8%)
# 149                      Saudi Arabia  ...        urdu (12%)
# 150                           Senegal  ...      arabic (11%)
# 151                            Serbia  ...      russian (2%)
# 152                        Seychelles  ...      spanish (8%)
# 153                      Sierra Leone  ...       arabic (5%)
# 154                         Singapore  ...   cantonese (10%)
# 155                          Slovakia  ...      russian (9%)
# 156                          Slovenia  ...      italian (7%)
# 157                   Solomon Islands  ...    japanese (13%)
# 158                           Somalia  ...      arabic (15%)
# 159                      South Africa  ...        dutch (2%)
# 160                       South Korea  ...     japanese (5%)
# 161                       South Sudan  ...     sudanese (8%)
# 162                             Spain  ...      english (7%)
# 163                         Sri Lanka  ...         urdu (4%)
# 164                             Sudan  ...    sudanese (10%)
# 165                          Suriname  ...      french (11%)
# 166                            Sweden  ...      spanish (4%)
# 167                       Switzerland  ...     english (11%)
# 168                             Syria  ...      english (6%)
# 169             São Tomé and Príncipe  ...      spanish (6%)
# 170                        Tajikistan  ...      persian (8%)
# 171                          Tanzania  ...       french (5%)
# 172                          Thailand  ...      burmese (6%)
# 173                       The Bahamas  ...       french (7%)
# 174                        The Gambia  ...      french (12%)
# 175                              Togo  ...       arabic (4%)
# 176                             Tonga  ...      spanish (5%)
# 177               Trinidad and Tobago  ...       creole (6%)
# 178                           Tunisia  ...      english (6%)
# 179                            Turkey  ...      english (5%)
# 180                      Turkmenistan  ...      arabic (10%)
# 181                            Tuvalu  ...       french (6%)
# 182                            Uganda  ...       french (3%)
# 183                           Ukraine  ...      english (4%)
# 184              United Arab Emirates  ...        urdu (18%)
# 185                    United Kingdom  ...         urdu (5%)
# 186                     United States  ...         urdu (8%)
# 187                           Uruguay  ...      italian (6%)
# 188                        Uzbekistan  ...       arabic (6%)
# 189                           Vanuatu  ...      spanish (6%)
# 190                      Vatican City  ...      spanish (7%)
# 191                         Venezuela  ...       french (6%)
# 192                           Vietnam  ...      english (3%)
# 193                             Yemen  ...      english (9%)
# 194                            Zambia  ...         urdu (3%)
# 195                          Zimbabwe  ...         urdu (3%)
#
# [196 rows x 4 columns]
